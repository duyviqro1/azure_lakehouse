# %% [markdown]
# # Tạo Catalog và các Schema cho các lớp Bronze, Silver và Gold

# %%
# %sql
CREATE CATALOG IF NOT EXISTS netflix_catalog;

CREATE SCHEMA IF NOT EXISTS netflix_catalog.bronze;
CREATE SCHEMA IF NOT EXISTS netflix_catalog.silver;
CREATE SCHEMA IF NOT EXISTS netflix_catalog.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
